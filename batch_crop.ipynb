# %%
import cv2 
import matplotlib.pyplot as plt

# %%
img = './src/dist_results/dist_frame_101351_False.jpg'
img = cv2.imread(img)

# %%
x_off = [10, 10]
crop = img[10:100, 20:110, :]

# %%
plt.imshow(crop)
